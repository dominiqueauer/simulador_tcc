# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'speed_vs_time_optmumlap_250.csv',
#  'teste2.csv',
#  'teste3.csv',
#  'Teste]',
#  'Untitled.ipynb']

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
kpi_values = pd.read_csv('teste3.csv', skiprows=8, sep=";", nrows=143, header=None)

# %%
kpi_values[:]
# Out:
#                                      0           1   2
# 0                         Lap time [s]   58.830837 NaN
# 1               Percent in Corners [%]   68.331488 NaN
# 2             Percent Accelerating [%]   50.436244 NaN
# 3                  Percent Braking [%]   49.138066 NaN
# 4                 Percent Coasting [%]    0.048516 NaN
# ..                                 ...         ...  ..
# 138  Minimum Speed in Sector 39 [km/h]   41.369645 NaN
# 139  Minimum Speed in Sector 40 [km/h]   41.712449 NaN
# 140  Minimum Speed in Sector 41 [km/h]   42.945115 NaN
# 141  Minimum Speed in Sector 42 [km/h]   43.274881 NaN
# 142              Percent in Gear 1 [%]  100.000000 NaN
#
# [143 rows x 3 columns]

# %%
kpi_values = kpi_values.set_index(0)[[1]]

# %%
kpi_values[:]
# Out:
#                                             1
# 0
# Lap time [s]                        58.830837
# Percent in Corners [%]              68.331488
# Percent Accelerating [%]            50.436244
# Percent Braking [%]                 49.138066
# Percent Coasting [%]                 0.048516
# ...                                       ...
# Minimum Speed in Sector 39 [km/h]   41.369645
# Minimum Speed in Sector 40 [km/h]   41.712449
# Minimum Speed in Sector 41 [km/h]   42.945115
# Minimum Speed in Sector 42 [km/h]   43.274881
# Percent in Gear 1 [%]              100.000000
#
# [143 rows x 1 columns]

# %%
energy = kpi_values.loc['Energy Spent [kJ]', 1]

# %%
energy
# Out:
# 516.559755958668

# %%
vehicle_parameters = pd.read_csv('teste3.csv', skiprows=153, sep=";", nrows=24, header=None)
vehicle_parameters = vehicle_parameters.set_index(0)[[1]]
vehicle_parameters[:]
# Out:
#                                              1
# 0
# Vehicle Mass [kg]                   357.000000
# Drag Coefficient [-]                  0.590000
# Downforce Coefficient [-]            -0.045000
# Aero Efficiency [-]                   0.076271
# Frontal Area [m^2]                    0.820000
# Drivetrain Efficiency [%]            92.380000
# Tire Rolling Radius [m]               0.254000
# Air Density [kg/m^3]                  1.227000
# Rev Limit [rpm]                    9000.000000
# Longitudinal Friction [-]             1.300000
# Lateral Friction [-]                  1.500000
# Final Drive Ratio [-]                 8.890000
# Fuel Energy Density [J/kg]       590000.000000
# Engine Thermal Efficiency [%]        79.060000
# Tire Rolling Drag [-]                 0.030000
# Power Scaling Factor [%]            200.000000
# Aero Scaling Factor [%]             100.000000
# Grip Scaling Factor [%]             100.000000
# Mass Lateral Friction [kg]          178.500000
# Mass Longitudinal Friction [kg]     178.500000
# Gear Shift Points [rpm]               0.000000
# Gear Ratio Data [-]                   0.000000
# Torque Data [N.m]                     0.000000
# RPM Data [rpm]                        0.000000

# %%
vehicle_kpis = pd.read_csv('teste3.csv', skiprows=179, sep=";", nrows=5, header=None)
vehicle_kpis = vehicle_kpis.set_index(0)[[1]]
vehicle_kpis[:]
# Out:
#                                                            1
# 0
# Deceleration Time For Speed [27,778 km/h] [s]       0.000000
# Deceleration Distance For Speed [27,778 km/h] [m]   0.000000
# Top Speed [km/h]                                   96.940573
# Acceleration Time To Speed [27,778 km/h] [s]        0.000000
# Acceleration Time For Distance [100 m] [s]         39.605005

# %%
simulation_results = pd.read_csv('teste3.csv', skiprows=186, sep=";")

# %%
simulation_results
# Out:
#                  speed          elapsedTime   elapsedDistance  \
# 0       Speed (linear)                 Time            Length
# 1                 km/h                    s                 m
# 2                  3.6  0.00371361533881089               0.1
# 3     3.63504043381523    0.103713615338811               0.2
# 4     5.62868876994689     0.20274965264147               0.3
# ...                ...                  ...               ...
# 7026  59.1867842966108     58.8065503898338  702.500000000091
# 7027   59.257875528914     58.8126328287478  702.600000000091
# 7028  59.3286829232653     58.8187079706051  702.700000000091
# 7029    59.39920827502     58.8247758619228  702.800000000091
# 7030  59.4694533621112     58.8308365487645   702.90000000009
#
#         lateralAcceleration longitudinalAcceleration      gear gearRatio  \
# 0     Acceleration (linear)    Acceleration (linear)  Unitless  Unitless
# 1                     m/s^2                    m/s^2         -         -
# 2          2.42724745056923        0.392464040211765         1      8.89
# 3       0.00342734842142223       0.0973345383756303         1      8.89
# 4       0.00825275432480778         5.59181505605482         1      8.89
# ...                     ...                      ...       ...       ...
# 7026                      0         3.25576661607863         1      8.89
# 7027                      0         3.24665233928407         1      8.89
# 7028                      0         3.23757388965685         1      8.89
# 7029                      0         3.22853104344626         1      8.89
# 7030                      0         3.21952357906039         1      8.89
#
#            engineSpeed            torque             power  \
# 0      Speed (angular)            Torque             Power
# 1                  rpm               N.m                hp
# 2                    1              15.6  19.7165833287418
# 3     337.478547805351                65  3.08052032845692
# 4     522.569623836685                65  4.77004052474316
# ...                ...               ...               ...
# 7026  5494.92375046963  41.5725178504338  32.0798663016192
# 7027  5501.52388773804  41.4782301751708  32.0455530466899
# 7028  5508.09767338215  41.3843189516836  32.0112030514869
# 7029  5514.64527408343  41.2907817988081  31.9768175236389
# 7030  5521.16685490588  41.1976163584875  31.9423976535285
#
#                 downForce          dragForce tractionControl  \
# 0                   Force              Force           Ratio
# 1                       N                  N               %
# 2             -0.02263815   215.221967469041               0
# 3     -0.0230809895171149  0.302617418113284               0
# 4     -0.0553414333190234  0.725587681293862               0
# ...                   ...                ...             ...
# 7026    -6.11906999747695   80.2278066335867               0
# 7027    -6.13377846612357   80.4206510002868               0
# 7028    -6.14844576055599   80.6129555272896               0
# 7029    -6.16307204269708    80.804722337584               0
# 7030    -6.17765747345676   80.9959535408775               0
#
#       throttlePosition brakePosition      cornerRadius sectorIndex  \
# 0                Ratio         Ratio            Length    Unitless
# 1                    %             %                 m           -
# 2     58.5704414697494             0  298.739130434783           1
# 3     99.9866981354675             0  297.478260869565           1
# 4     99.9681060359871             0  296.217391304348           1
# ...                ...           ...               ...         ...
# 7026               100             0                 0          42
# 7027               100             0                 0          42
# 7028               100             0                 0          42
# 7029               100             0                 0          42
# 7030               100             0                 0          42
#
#      maximumCornerSpeed loadSensitiveLatGrip loadSensitiveLongGrip  \
# 0        Speed (linear)             Unitless              Unitless
# 1                  km/h                    -                     -
# 2      96.9405733107708                  1.5                   1.3
# 3      96.9405733107708                  1.3                   1.5
# 4      96.9405733107708                  1.3                   1.5
# ...                 ...                  ...                   ...
# 7026                  0                  1.5                   1.3
# 7027                  0                  1.5                   1.3
# 7028                  0                  1.5                   1.3
# 7029                  0                  1.5                   1.3
# 7030                  0                  1.5                   1.3
#
#                 yawangle           yawvelocity         yawacceleration  \
# 0                  Angle       Speed (angular)  Acceleration (angular)
# 1                    deg                   rpm                 deg/s^2
# 2                      0                     0                       0
# 3     0.0192195011507793    0.0275144582729187      0.0288130733259014
# 4     0.0385206354711478    0.0407747696472069      0.0140213259511001
# ...                  ...                   ...                     ...
# 7026   -111.110739860626  6.34823384708274E-70   -2.18328140638331E-68
# 7027   -111.110739860626  2.11607794902758E-70   -7.28639178361081E-69
# 7028   -111.110739860626  7.05359316342526E-71   -2.43171457107887E-69
# 7029   -111.110739860626                     0   -1.21731011666987E-69
# 7030   -111.110739860626                     0                       0
#
#                 xposition            yposition trackelevation  \
# 0                  Length               Length         Length
# 1                       m                    m              m
# 2     -0.0999844755472975  0.00176197507247602              0
# 3      -0.199969534066616  0.00349055215187093              0
# 4      -0.299955166796705  0.00518558978900694              0
# ...                   ...                  ...            ...
# 7026     56.7724810876553    -106.376434006247              0
# 7027     56.8101054417243    -106.283781925963              0
# 7028     56.8477297957932     -106.19112984568              0
# 7029     56.8853541498621    -106.098477765396              0
# 7030     56.9229785039307    -106.005825685113              0
#
#                     fz  Unnamed: 27
# 0                Force          NaN
# 1                    N          NaN
# 2        3502.14736185          NaN
# 3     3502.14691901048          NaN
# 4     3502.11465856668          NaN
# ...                ...          ...
# 7026  3496.05093000252          NaN
# 7027  3496.03622153388          NaN
# 7028  3496.02155423944          NaN
# 7029   3496.0069279573          NaN
# 7030  3495.99234252654          NaN
#
# [7031 rows x 28 columns]

# %%
simulation_results = simulation_results.drop([0, 1])

# %%
for column in simulation_results:
    simulation_results[column] = simulation_results[column].astype(float)

# %%
simulation_results.dtypes
# Out:
# speed                       float64
# elapsedTime                 float64
# elapsedDistance             float64
# lateralAcceleration         float64
# longitudinalAcceleration    float64
# gear                        float64
# gearRatio                   float64
# engineSpeed                 float64
# torque                      float64
# power                       float64
# downForce                   float64
# dragForce                   float64
# tractionControl             float64
# throttlePosition            float64
# brakePosition               float64
# cornerRadius                float64
# sectorIndex                 float64
# maximumCornerSpeed          float64
# loadSensitiveLatGrip        float64
# loadSensitiveLongGrip       float64
# yawangle                    float64
# yawvelocity                 float64
# yawacceleration             float64
# xposition                   float64
# yposition                   float64
# trackelevation              float64
# fz                          float64
# Unnamed: 27                 float64
# dtype: object

# %%
simulation_results
# Out:
#           speed  elapsedTime  elapsedDistance  lateralAcceleration  \
# 2      3.600000     0.003714              0.1             2.427247
# 3      3.635040     0.103714              0.2             0.003427
# 4      5.628689     0.202750              0.3             0.008253
# 5      6.915926     0.266708              0.4             0.012512
# 6      7.963381     0.318761              0.5             0.016661
# ...         ...          ...              ...                  ...
# 7026  59.186784    58.806550            702.5             0.000000
# 7027  59.257876    58.812633            702.6             0.000000
# 7028  59.328683    58.818708            702.7             0.000000
# 7029  59.399208    58.824776            702.8             0.000000
# 7030  59.469453    58.830837            702.9             0.000000
#
#       longitudinalAcceleration  gear  gearRatio  engineSpeed     torque  \
# 2                     0.392464   1.0       8.89     1.000000  15.600000
# 3                     0.097335   1.0       8.89   337.478548  65.000000
# 4                     5.591815   1.0       8.89   522.569624  65.000000
# 5                     5.590633   1.0       8.89   642.077265  65.000000
# 6                     5.589599   1.0       8.89   739.323377  65.000000
# ...                        ...   ...        ...          ...        ...
# 7026                  3.255767   1.0       8.89  5494.923750  41.572518
# 7027                  3.246652   1.0       8.89  5501.523888  41.478230
# 7028                  3.237574   1.0       8.89  5508.097673  41.384319
# 7029                  3.228531   1.0       8.89  5514.645274  41.290782
# 7030                  3.219524   1.0       8.89  5521.166855  41.197616
#
#           power  downForce   dragForce  tractionControl  throttlePosition  \
# 2     19.716583  -0.022638  215.221967              0.0         58.570441
# 3      3.080520  -0.023081    0.302617              0.0         99.986698
# 4      4.770041  -0.055341    0.725588              0.0         99.968106
# 5      5.860912  -0.083548    1.095409              0.0         99.951850
# 6      6.748579  -0.110772    1.452347              0.0         99.936161
# ...         ...        ...         ...              ...               ...
# 7026  32.079866  -6.119070   80.227807              0.0        100.000000
# 7027  32.045553  -6.133778   80.420651              0.0        100.000000
# 7028  32.011203  -6.148446   80.612956              0.0        100.000000
# 7029  31.976818  -6.163072   80.804722              0.0        100.000000
# 7030  31.942398  -6.177657   80.995954              0.0        100.000000
#
#       brakePosition  cornerRadius  sectorIndex  maximumCornerSpeed  \
# 2               0.0    298.739130          1.0           96.940573
# 3               0.0    297.478261          1.0           96.940573
# 4               0.0    296.217391          1.0           96.940573
# 5               0.0    294.956522          1.0           96.940573
# 6               0.0    293.695652          1.0           96.940573
# ...             ...           ...          ...                 ...
# 7026            0.0      0.000000         42.0            0.000000
# 7027            0.0      0.000000         42.0            0.000000
# 7028            0.0      0.000000         42.0            0.000000
# 7029            0.0      0.000000         42.0            0.000000
# 7030            0.0      0.000000         42.0            0.000000
#
#       loadSensitiveLatGrip  loadSensitiveLongGrip    yawangle   yawvelocity  \
# 2                      1.5                    1.3    0.000000  0.000000e+00
# 3                      1.3                    1.5    0.019220  2.751446e-02
# 4                      1.3                    1.5    0.038521  4.077477e-02
# 5                      1.3                    1.5    0.057904  5.445418e-02
# 6                      1.3                    1.5    0.077371  6.581277e-02
# ...                    ...                    ...         ...           ...
# 7026                   1.5                    1.3 -111.110740  6.348234e-70
# 7027                   1.5                    1.3 -111.110740  2.116078e-70
# 7028                   1.5                    1.3 -111.110740  7.053593e-71
# 7029                   1.5                    1.3 -111.110740  0.000000e+00
# 7030                   1.5                    1.3 -111.110740  0.000000e+00
#
#       yawacceleration  xposition   yposition  trackelevation           fz  \
# 2        0.000000e+00  -0.099984    0.001762             0.0  3502.147362
# 3        2.881307e-02  -0.199970    0.003491             0.0  3502.146919
# 4        1.402133e-02  -0.299955    0.005186             0.0  3502.114659
# 5        2.239756e-02  -0.399941    0.006847             0.0  3502.086452
# 6        2.285079e-02  -0.499928    0.008474             0.0  3502.059228
# ...               ...        ...         ...             ...          ...
# 7026    -2.183281e-68  56.772481 -106.376434             0.0  3496.050930
# 7027    -7.286392e-69  56.810105 -106.283782             0.0  3496.036222
# 7028    -2.431715e-69  56.847730 -106.191130             0.0  3496.021554
# 7029    -1.217310e-69  56.885354 -106.098478             0.0  3496.006928
# 7030     0.000000e+00  56.922979 -106.005826             0.0  3495.992343
#
#       Unnamed: 27
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# ...           ...
# 7026          NaN
# 7027          NaN
# 7028          NaN
# 7029          NaN
# 7030          NaN
#
# [7029 rows x 28 columns]

# %%
simulation_results['speed_quadrado'] = simulation_results['speed'] ** 2
